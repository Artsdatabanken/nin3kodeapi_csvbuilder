# %%
import json

def print_json_attributes(json_string, prefix=""):
  data = json.loads(json_string)
  for key, value in data.items():
    if isinstance(value, dict):
      print_json_attributes(json.dumps(value), prefix + key + ".")
    elif isinstance(value, list):
      for i, item in enumerate(value):
        if isinstance(item, dict):
          print_json_attributes(json.dumps(item), prefix + key + "[ ].")
        else:
          print(prefix + key + "[ ]")
    else:
      print(prefix + key)

# Example usage
#filename = 'KodeforType_schema.json'
filename = 'KodeforHovedtype_schema.json'
with open(filename, 'r') as file:
  json_string = file.read()

print_json_attributes(json_string)
# Out:
# navn
# kategori
# kode.id
# kode.definisjon
# kode.langkode
# prosedyrekategoriEnum
# prosedyrekategoriNavn
# variabeltrinn[ ].variabelnavn.navn
# variabeltrinn[ ].variabelnavn.kode.id
# variabeltrinn[ ].variabelnavn.kode.definisjon
# variabeltrinn[ ].variabelnavn.kode.langkode
# variabeltrinn[ ].variabelnavn.variabelkategori2Enum
# variabeltrinn[ ].variabelnavn.variabelkategori2Navn
# variabeltrinn[ ].variabelnavn.variabeltypeEnum
# variabeltrinn[ ].variabelnavn.variabeltypeNavn
# variabeltrinn[ ].variabelnavn.variabelgruppeEnum
# variabeltrinn[ ].variabelnavn.variabelgruppeNavn
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalaNavn
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalatypeEnum
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalatypeNavn
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].enhetEnum
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].enhetNavn
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].verdi
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].kode
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].beskrivelse
# variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].registert
# variabeltrinn[ ].maaleskala.maaleskalaNavn
# variabeltrinn[ ].maaleskala.maaleskalatypeEnum
# variabeltrinn[ ].maaleskala.maaleskalatypeNavn
# variabeltrinn[ ].maaleskala.enhetEnum
# variabeltrinn[ ].maaleskala.enhetNavn
# variabeltrinn[ ].maaleskala.trinn[ ].verdi
# variabeltrinn[ ].maaleskala.trinn[ ].kode
# variabeltrinn[ ].maaleskala.trinn[ ].beskrivelse
# variabeltrinn[ ].maaleskala.trinn[ ].registert
# grunntyper[ ].navn
# grunntyper[ ].kategori
# grunntyper[ ].kode.id
# grunntyper[ ].kode.definisjon
# grunntyper[ ].kode.langkode
# grunntyper[ ].variabeltrinn[ ].variabelnavn.navn
# grunntyper[ ].variabeltrinn[ ].variabelnavn.kode.id
# grunntyper[ ].variabeltrinn[ ].variabelnavn.kode.definisjon
# grunntyper[ ].variabeltrinn[ ].variabelnavn.kode.langkode
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabelkategori2Enum
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabelkategori2Navn
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltypeEnum
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltypeNavn
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabelgruppeEnum
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabelgruppeNavn
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalaNavn
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalatypeEnum
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalatypeNavn
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].enhetEnum
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].enhetNavn
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].verdi
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].kode
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].beskrivelse
# grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].registert
# grunntyper[ ].variabeltrinn[ ].maaleskala.maaleskalaNavn
# grunntyper[ ].variabeltrinn[ ].maaleskala.maaleskalatypeEnum
# grunntyper[ ].variabeltrinn[ ].maaleskala.maaleskalatypeNavn
# grunntyper[ ].variabeltrinn[ ].maaleskala.enhetEnum
# grunntyper[ ].variabeltrinn[ ].maaleskala.enhetNavn
# grunntyper[ ].variabeltrinn[ ].maaleskala.trinn[ ].verdi
# grunntyper[ ].variabeltrinn[ ].maaleskala.trinn[ ].kode
# grunntyper[ ].variabeltrinn[ ].maaleskala.trinn[ ].beskrivelse
# grunntyper[ ].variabeltrinn[ ].maaleskala.trinn[ ].registert
# grunntyper[ ].konverteringer[ ].kode
# grunntyper[ ].konverteringer[ ].forrigeKode
# grunntyper[ ].konverteringer[ ].klasse
# grunntyper[ ].konverteringer[ ].klasseNavn
# grunntyper[ ].konverteringer[ ].forrigeVersjon
# grunntyper[ ].konverteringer[ ].foelsomhetsPresisjon
# grunntyper[ ].konverteringer[ ].spesifiseringsevne
# grunntyper[ ].konverteringer[ ].url
# kartleggingsenheter[ ].kategori
# kartleggingsenheter[ ].maalestokkEnum
# kartleggingsenheter[ ].maalestokkNavn
# kartleggingsenheter[ ].navn
# kartleggingsenheter[ ].kode.id
# kartleggingsenheter[ ].kode.definisjon
# kartleggingsenheter[ ].kode.langkode
# kartleggingsenheter[ ].grunntyper[ ].navn
# kartleggingsenheter[ ].grunntyper[ ].kategori
# kartleggingsenheter[ ].grunntyper[ ].kode.id
# kartleggingsenheter[ ].grunntyper[ ].kode.definisjon
# kartleggingsenheter[ ].grunntyper[ ].kode.langkode
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.navn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.kode.id
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.kode.definisjon
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.kode.langkode
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabelkategori2Enum
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabelkategori2Navn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltypeEnum
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltypeNavn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabelgruppeEnum
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabelgruppeNavn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalaNavn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalatypeEnum
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].maaleskalatypeNavn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].enhetEnum
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].enhetNavn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].verdi
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].kode
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].beskrivelse
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].variabelnavn.variabeltrinn[ ].trinn[ ].registert
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.maaleskalaNavn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.maaleskalatypeEnum
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.maaleskalatypeNavn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.enhetEnum
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.enhetNavn
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.trinn[ ].verdi
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.trinn[ ].kode
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.trinn[ ].beskrivelse
# kartleggingsenheter[ ].grunntyper[ ].variabeltrinn[ ].maaleskala.trinn[ ].registert
# kartleggingsenheter[ ].grunntyper[ ].konverteringer[ ].kode
# kartleggingsenheter[ ].grunntyper[ ].konverteringer[ ].forrigeKode
# kartleggingsenheter[ ].grunntyper[ ].konverteringer[ ].klasse
# kartleggingsenheter[ ].grunntyper[ ].konverteringer[ ].klasseNavn
# kartleggingsenheter[ ].grunntyper[ ].konverteringer[ ].forrigeVersjon
# kartleggingsenheter[ ].grunntyper[ ].konverteringer[ ].foelsomhetsPresisjon
# kartleggingsenheter[ ].grunntyper[ ].konverteringer[ ].spesifiseringsevne
# kartleggingsenheter[ ].grunntyper[ ].konverteringer[ ].url
# konverteringer[ ].kode
# konverteringer[ ].forrigeKode
# konverteringer[ ].klasse
# konverteringer[ ].klasseNavn
# konverteringer[ ].forrigeVersjon
# konverteringer[ ].foelsomhetsPresisjon
# konverteringer[ ].spesifiseringsevne
# konverteringer[ ].url
